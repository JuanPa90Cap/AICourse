# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/stock
# Out:
# TrainAndValid.csv

# %%
# !unzip TrainAndValid.csv.z
# Out:
# unzip:  cannot find or open TrainAndValid.csv.z, TrainAndValid.csv.z.zip or TrainAndValid.csv.z.ZIP.

# %%
# !ls /content/drive/MyDrive/stock
# Out:
# TrainAndValid.csv

# %%
df = pd.read_csv("/content/drive/MyDrive/stock/TrainAndValid.csv")
df.head()
# Out:
# <ipython-input-6-6f57e9e5ca24>:1: DtypeWarning: Columns (13,39,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/stock/TrainAndValid.csv")
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  object
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %%
df.shape
# Out:
# (412698, 53)

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# 3                    3486.0      High   5/19/2011 0:00  ...
# 4                     722.0    Medium   7/23/2009 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# ...

# %%
df.tail()
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 412693  6333344    10000.0    1919201    21435         149           2.0
# 412694  6333345    10500.0    1882122    21436         149           2.0
# 412695  6333347    12500.0    1944213    21435         149           2.0
# 412696  6333348    10000.0    1794518    21435         149           2.0
# 412697  6333349    13000.0    1944743    21436         149           2.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand        saledate  ...  \
# 412693      2005                       NaN       NaN   3/7/2012 0:00  ...
# 412694      2005                       NaN       NaN  1/28/2012 0:00  ...
# 412695      2005                       NaN       NaN  1/28/2012 0:00  ...
# 412696      2006                       NaN       NaN   3/7/2012 0:00  ...
# 412697      2006                       NaN       NaN  1/28/2012 0:00  ...
#
#        Undercarriage_Pad_Width         Stick_Length                Thumb  \
# ...

# %%
for col in df.columns:
  print(col)
  print(df[col].unique()[:5])
# Out:
# SalesID
# [1139246 1139248 1139249 1139251 1139253]
# SalePrice
# [66000. 57000. 10000. 38500. 11000.]
# MachineID
# [ 999089  117657  434808 1026470 1057373]
# ModelID
# [ 3157    77  7009   332 17311]
# datasource
# [121 132 136 149 172]
# auctioneerID
# [ 3.  1.  2. 11.  4.]
# YearMade
# [2004 1996 2001 2007 1993]
# MachineHoursCurrentMeter
# [  68. 4640. 2838. 3486.  722.]
# UsageBand
# ['Low' 'High' 'Medium' nan]
# saledate
# ['11/16/2006 0:00' '3/26/2004 0:00' '2/26/2004 0:00' '5/19/2011 0:00'
#  '7/23/2009 0:00']
# fiModelDesc
# ['521D' '950FII' '226' 'PC120-6E' 'S175']
# fiBaseModel
# ['521' '950' '226' 'PC120' 'S175']
# fiSecondaryDesc
# ['D' 'F' nan 'G' 'E']
# fiModelSeries
# [nan 'II' '-6E' 'LC' '-5']
# fiModelDescriptor
# [nan 'LC' '6' 'L' 'LT']
# ProductSize
# [nan 'Medium' 'Small' 'Large / Medium' 'Mini']
# fiProductClassDesc
# ['Wheel Loader - 110.0 to 120.0 Horsepower'
#  'Wheel Loader - 150.0 to 175.0 Horsepower'
# ...

# %%
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %%
df.describe()
# Out:
#             SalesID      SalePrice     MachineID        ModelID  \
# count  4.126980e+05  412698.000000  4.126980e+05  412698.000000
# mean   2.011161e+06   31215.181414  1.230061e+06    6947.201828
# std    1.080068e+06   23141.743695  4.539533e+05    6280.824982
# min    1.139246e+06    4750.000000  0.000000e+00      28.000000
# 25%    1.421898e+06   14500.000000  1.088593e+06    3261.000000
# 50%    1.645852e+06   24000.000000  1.284397e+06    4605.000000
# 75%    2.261012e+06   40000.000000  1.478079e+06    8899.000000
# max    6.333349e+06  142000.000000  2.486330e+06   37198.000000
#
#           datasource   auctioneerID       YearMade  MachineHoursCurrentMeter
# count  412698.000000  392562.000000  412698.000000              1.475040e+05
# mean      135.169361       6.585268    1899.049637              3.522988e+03
# std         9.646749      17.158409     292.190243              2.716993e+04
# min       121.000000       0.000000    1000.000000              0.000000e+00
# ...

# %% [markdown]
# ## Análisis inicial
#
#
# *   Tenemos 412698 filas y 53 columnas
# *   Hay muchos valores faltantes
# *   La columna saledate es de tipo objeto, tenemos que convertir en un objeto datetime.
# *   La mayoría de las columnas son de tipo de dato string, le podemos convertir en un tipo de dato categórico

# %%
df1 = pd.read_csv("/content/drive/MyDrive/stock/TrainAndValid.csv", low_memory=False, parse_dates=['saledate'])

# %%
df1.saledate.head(5)
# Out:
# 0   2006-11-16
# 1   2004-03-26
# 2   2004-02-26
# 3   2011-05-19
# 4   2009-07-23
# Name: saledate, dtype: datetime64[ns]

# %% [markdown]
# Ahora tenemos la columna saledate como "datetime" pero vemos que está desorden por lo que vamos a ordendar de forma ascendente.

# %% [markdown]
# ### Ordenar el Dataframe por saledate

# %%
df1.sort_values(by=["saledate"], inplace=True, ascending=True)

# %%
df1.saledate.head(3)
# Out:
# 205615   1989-01-17
# 274835   1989-01-31
# 141296   1989-01-31
# Name: saledate, dtype: datetime64[ns]

# %% [markdown]
# ## Creamos nuevas columnas
# Creamos las columnas año(saleyear),mes(salemonth), día(saleday), día de la semana(saledayofweek), día del año(saledayofyear)

# %%
df1["saleyear"] = df1.saledate.dt.year
df1["salemonth"] = df1.saledate.dt.month
df1["saleday"] = df1.saledate.dt.day
df1["saledayofweek"] = df1.saledate.dt.dayofweek
df1["saledayofyear"] = df1.saledate.dt.dayofyear

df1.head(3)
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  ...  \
# 205615      1974                       NaN       NaN 1989-01-17  ...
# 274835      1980                       NaN       NaN 1989-01-31  ...
# 141296      1978                       NaN       NaN 1989-01-31  ...
#
#            Backhoe_Mounting Blade_Type      Travel_Controls Differential_Type  \
# 205615  None or Unspecified   Straight  None or Unspecified               NaN
# 274835                  NaN        NaN                  NaN          Standard
# 141296  None or Unspecified   Straight  None or Unspecified               NaN
#
#        Steering_Controls saleyear salemonth saleday saledayofweek  \
# ...

# %%
df1.drop("saledate", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-4d6ecfee79f7> in <cell line: 1>()
# ----> 1 df1.drop("saledate", axis=1, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %% [markdown]
# ### Convertir los string en category
# Strings no se utiliza en los modelos de Machine Learning por lo que necesitamos convertirlo en category y luego en tipo de dato numérico

# %%
list(df1.dtypes[df1.dtypes == 'object'].index)
# Out:
# ['UsageBand',
#  'fiModelDesc',
#  'fiBaseModel',
#  'fiSecondaryDesc',
#  'fiModelSeries',
#  'fiModelDescriptor',
#  'ProductSize',
#  'fiProductClassDesc',
#  'state',
#  'ProductGroup',
#  'ProductGroupDesc',
#  'Drive_System',
#  'Enclosure',
#  'Forks',
#  'Pad_Type',
#  'Ride_Control',
#  'Stick',
#  'Transmission',
#  'Turbocharged',
#  'Blade_Extension',
#  'Blade_Width',
#  'Enclosure_Type',
#  'Engine_Horsepower',
#  'Hydraulics',
#  'Pushblock',
#  'Ripper',
#  'Scarifier',
#  'Tip_Control',
#  'Tire_Size',
#  'Coupler',
#  'Coupler_System',
#  'Grouser_Tracks',
#  'Hydraulics_Flow',
#  'Track_Type',
#  'Undercarriage_Pad_Width',
#  'Stick_Length',
#  'Thumb',
#  'Pattern_Changer',
#  'Grouser_Type',
#  'Backhoe_Mounting',
#  'Blade_Type',
#  'Travel_Controls',
#  'Differential_Type',
#  'Steering_Controls']

# %%
string_columns = df1.dtypes[df1.dtypes == 'object'].index
string_columns
# Out:
# Index(['UsageBand', 'fiModelDesc', 'fiBaseModel', 'fiSecondaryDesc',
#        'fiModelSeries', 'fiModelDescriptor', 'ProductSize',
#        'fiProductClassDesc', 'state', 'ProductGroup', 'ProductGroupDesc',
#        'Drive_System', 'Enclosure', 'Forks', 'Pad_Type', 'Ride_Control',
#        'Stick', 'Transmission', 'Turbocharged', 'Blade_Extension',
#        'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Hydraulics',
#        'Pushblock', 'Ripper', 'Scarifier', 'Tip_Control', 'Tire_Size',
#        'Coupler', 'Coupler_System', 'Grouser_Tracks', 'Hydraulics_Flow',
#        'Track_Type', 'Undercarriage_Pad_Width', 'Stick_Length', 'Thumb',
#        'Pattern_Changer', 'Grouser_Type', 'Backhoe_Mounting', 'Blade_Type',
#        'Travel_Controls', 'Differential_Type', 'Steering_Controls'],
#       dtype='object')

# %%
for col in string_columns:
  df1[col] = df1[col].astype('category').cat.as_ordered()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   category
#  9   fiModelDesc               412698 non-null  category
#  10  fiBaseModel               412698 non-null  category
#  11  fiSecondaryDesc           271971 non-null  category
#  12  fiModelSeries             58667 non-null   category
# ...

# %% [markdown]
# #### Otra forma de iterar los elementos de un DataFrame

# %%
#No correr esta linea de código
for label, content in df1.items():
    if pd.api.types.is_string_dtype(content):
        df1[label] = content.astype("category").cat.as_ordered()

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   category
#  9   fiModelDesc               412698 non-null  category
#  10  fiBaseModel               412698 non-null  category
#  11  fiSecondaryDesc           271971 non-null  category
#  12  fiModelSeries             58667 non-null   category
# ...

# %% [markdown]
# ### Completar valores faltantes de columnas con tipo de dato numérico

# %%
#Cuales columnas con tipo numérica
for label, content in df1.items():
  if pd.api.types.is_numeric_dtype(content):
    print(label)
# Out:
# SalesID
# SalePrice
# MachineID
# ModelID
# datasource
# auctioneerID
# YearMade
# MachineHoursCurrentMeter
# saleyear
# salemonth
# saleday
# saledayofweek
# saledayofyear

# %%
#Cuales son las columnas con datos numéricos faltantes
for label, content in df1.items():
  if pd.api.types.is_numeric_dtype(content):
    if pd.isnull(content).sum():
      print(label)
# Out:
# auctioneerID
# MachineHoursCurrentMeter

# %%
for label, content in df1.items():
  if pd.api.types.is_numeric_dtype(content):
    if pd.isnull(content).sum():
      df1[label] = content.fillna(content.median())

# %%
#Comprubo que en las dos columnas ya no tenga datos faltantes
df1['auctioneerID'].isnull().sum()
# Out:
# 0

# %%
#Comprubo que en las dos columnas ya no tenga datos faltantes
df1['MachineHoursCurrentMeter'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Completar los valores faltantes(Categóricos)

# %%
#Columnas con valores faltantes
for label, content in df1.items():
  if not pd.api.types.is_numeric_dtype(content):
    if pd.isnull(content).sum():
      print(label)
# Out:
# UsageBand
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
for label, content in df1.items():
  if not pd.api.types.is_numeric_dtype(content):
    df1[label+"_is_missing"]  = pd.isnull(content)
    df1[label] = pd.Categorical(content).codes+1

# %%
df1.Steering_Controls[:100]
# Out:
# 205615    0
# 274835    2
# 141296    0
# 212552    2
# 62755     0
#          ..
# 113454    0
# 62665     0
# 78445     0
# 233279    0
# 28223     0
# Name: Steering_Controls, Length: 100, dtype: int8

# %%
df1.isna().sum()
# Out:
# SalesID                         0
# SalePrice                       0
# MachineID                       0
# ModelID                         0
# datasource                      0
#                                ..
# Backhoe_Mounting_is_missing     0
# Blade_Type_is_missing           0
# Travel_Controls_is_missing      0
# Differential_Type_is_missing    0
# Steering_Controls_is_missing    0
# Length: 101, dtype: int64

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(6, 4))

sns.histplot(df1.SalePrice[df.SalePrice < 60000], bins=40, alpha=1)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Distribution of prices')

plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(df["saledate"][:1000], df["SalePrice"][:1000])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
